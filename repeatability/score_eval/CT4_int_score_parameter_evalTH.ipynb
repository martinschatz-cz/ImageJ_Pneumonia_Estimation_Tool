# %%
import pandas as pd

# %%
df = pd.read_csv("./CT4_score_parameter_evalTH_5.csv",sep=",")
df['th_intDen']=(df['th_intDen']/df['th_intDen'].max())*1
df
# Out:
#       thL  thU  Score  th_intDen
# 0       0    0      0   0.000000
# 1       0    1      0   0.000000
# 2       0    2      0   0.000000
# 3       0    3      0   0.000020
# 4       0    4      0   0.000020
# ...   ...  ...    ...        ...
# 4945   96   97      0   0.000000
# 4946   96   98      0   0.000264
# 4947   97   97      0   0.000000
# 4948   97   98      0   0.000024
# 4949   98   98      0   0.000000
#
# [4950 rows x 4 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
#cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
cmap = sns.color_palette("coolwarm", as_cmap=True)
g = sns.relplot(
    data=df,
    x="thL", y="thU",
    hue="Score", size="th_intDen",
    palette=cmap, sizes=(10, 200),
)
g.set(
    xlabel="Lower threshold",
    ylabel="Upper threshold",
    title="Score evaluation over whole brightness settings"
)
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
g.figure.savefig("CT4_int_score_th_range.png")
