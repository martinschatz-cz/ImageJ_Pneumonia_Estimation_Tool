# %%
import pandas as pd

# %%
df = pd.read_csv("./CT2_score_parameter_evalTH_5.csv",sep=",")
df['th_intDen']=(df['th_intDen']/df['th_intDen'].max())*1
df
# Out:
#      thL  thU  Score  th_intDen
# 0      0    0      0   0.000000
# 1      0    5      0   0.002017
# 2      0   10      1   0.056126
# 3      0   15      2   0.155013
# 4      0   20      3   0.375719
# ..   ...  ...    ...        ...
# 271  100  105      0   0.000053
# 272  100  110      0   0.000329
# 273  105  105      0   0.000000
# 274  105  110      0   0.000074
# 275  110  110      0   0.000000
#
# [276 rows x 4 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
#cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
cmap = sns.color_palette("coolwarm", as_cmap=True)
g = sns.relplot(
    data=df,
    x="thL", y="thU",
    hue="Score", size="th_intDen",
    palette=cmap, sizes=(10, 200),
)
g.set(
    xlabel="Lower threshold",
    ylabel="Upper threshold",
    title="Score evaluation over whole brightness settings"
)
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
g.figure.savefig("CT2_int_score_th_range.png")
