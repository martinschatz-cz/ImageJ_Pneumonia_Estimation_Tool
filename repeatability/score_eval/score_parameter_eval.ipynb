# %%
import pandas as pd

# %%
df = pd.read_csv("./Log_covTH_5.csv",sep=",")
df
# Out:
#       thL  thU  Score
# 0       0    0      0
# 1       0    5      0
# 2       0   10      1
# 3       0   15      2
# 4       0   20      3
# ...   ...  ...    ...
# 1321  240  245      0
# 1322  240  250      0
# 1323  245  245      0
# 1324  245  250      0
# 1325  250  250      0
#
# [1326 rows x 3 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
#cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
cmap = sns.color_palette("coolwarm", as_cmap=True)
g = sns.relplot(
    data=df,
    x="thL", y="thU",
    hue="Score", size="Score",
    palette=cmap, sizes=(10, 200),
)
g.set(
    xlabel="Lower threshold",
    ylabel="Upper threshold",
    title="Score evaluation over whole brightness settings"
)
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
g.figure.savefig("score_th_range.png")
