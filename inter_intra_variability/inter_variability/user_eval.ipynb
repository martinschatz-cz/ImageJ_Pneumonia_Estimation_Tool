# %%
# !pip install watermark
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.1 MB/s eta 0:00:00
# ...

# %%
from watermark import watermark
print(watermark(current_time=True,packages="pandas,matplotlib,seaborn"))
# Out:
# pandas    : 2.2.2
# matplotlib: 3.10.0
# seaborn   : 0.13.2

# %%
# This shows the default Python in Colab
# !python -V
# Out:
# Python 3.11.11

# %%
import pandas as pd

# %%
df = pd.read_csv("./users_result.csv",sep=";")
df
# Out:
#    dataset   user  ct_start  ct_end  lung_th1  lung_th2  pn_th1  pn_th2  \
# 0    CT1_1  user1        56     524         0       167      43     158
# 1    CT1_2  user1        12     106         0       160      39     143
# 2      CT2  user1         6      93         0       113      35     118
# 3      CT3  user1        50     396         0        91      35     105
# 4      CT4  user1         7      69         0        99      50     108
# 5      CT5  user1         8      92         0        77      30      85
# 6    CT1_1  user2        63     484         0       160      50     181
# 7    CT1_2  user2        14      96         0       123      48     126
# 8      CT2  user2         9      84         0       112      41     103
# 9      CT3  user2        59     387         0        69      35      68
# 10     CT4  user2        11      68         0       105      35     100
# 11     CT5  user2        11      90         0        88      30     119
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


# Plot the orbital period with horizontal boxes
sns.boxplot(x="score", y="dataset", data=df,
            whis=[0, 100], width=.6, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="score", y="dataset", data=df,
              size=4, color=".3", linewidth=0)

ax.set(
    xlabel="Score",
    ylabel="Dataset",
    title="Variance of score results"
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
plt.savefig("inter-var-score_plot.png")
plt.show()
# Out:
# <ipython-input-7-d06053709055>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="score", y="dataset", data=df,

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


# Plot the orbital period with horizontal boxes
sns.boxplot(x="pn_th1", y="dataset", data=df,
            whis=[0, 100], width=.6, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="pn_th1", y="dataset", data=df,
              size=4, color=".3", linewidth=0)

ax.set(
    xlabel="Threshold",
    ylabel="Dataset",
    title="Variance of lower threshold for pneumonia"
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
plt.savefig("inter-var-score_lowerTH_plot.png")
plt.show()
# Out:
# <ipython-input-8-40f6dec741ca>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="pn_th1", y="dataset", data=df,

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


# Plot the orbital period with horizontal boxes
sns.boxplot(x="pn_th2", y="dataset", data=df,
            whis=[0, 100], width=.6, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="pn_th2", y="dataset", data=df,
              size=4, color=".3", linewidth=0)

ax.set(
    xlabel="Threshold",
    ylabel="Dataset",
    title="Variance of upper threshold for pneumonia"
)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
plt.savefig("inter-var-score_upperTH_plot.png")
plt.show()
# Out:
# <ipython-input-9-cd886b50e032>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="pn_th2", y="dataset", data=df,
